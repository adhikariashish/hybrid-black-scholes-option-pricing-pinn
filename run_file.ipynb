# %% [markdown]
#   To access files in your Google Drive, you'll need to mount it. This will prompt you to authorize Colab to access your Drive files.

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn')

print(os.getcwd())

# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# app	 docs	  notebooks	  reports	  scripts	  tests
# configs  env	  pyproject.toml  run_file.ipynb  src
# data	 LICENSE  README.md	  runs		  test_run.ipynb

# %%
! python -m src.training.train
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ep     1/5000 | loss=6.423e+05 (pde=3.58e-04, term=8.75e+03, bc=2.05e+04) | 1.0s
# ep   100/5000 | loss=5.047e+05 (pde=8.38e-01, term=6.67e+03, bc=1.71e+04) | 54.3s
# ep   200/5000 | loss=4.387e+05 (pde=2.24e+00, term=5.71e+03, bc=1.53e+04) | 108.8s
# ep   300/5000 | loss=3.953e+05 (pde=3.96e+00, term=5.10e+03, bc=1.40e+04) | 164.6s
# ep   400/5000 | loss=3.680e+05 (pde=5.77e+00, term=4.75e+03, bc=1.31e+04) | 221.3s
# ep   500/5000 | loss=3.518e+05 (pde=7.48e+00, term=4.55e+03, bc=1.24e+04) | 278.7s
# ...

# %%
! python -m src.evaluation.greek --ckpt runs/pinn_001/checkpoint_call.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [t=0.000] price RMSE=0.584305, max_abs_err=2.877909 | delta RMSE=0.025005 | gamma RMSE=0.002253 | theta RMSE=1.642446
# [t=0.000] worst at S=300.000000: PINN=201.999148, BS=204.877058, err=-2.877909
# [t=0.500] price RMSE=0.141732, max_abs_err=0.772213 | delta RMSE=0.012134 | gamma RMSE=0.001507 | theta RMSE=0.636293
# [t=0.500] worst at S=300.000000: PINN=201.696796, BS=202.469009, err=-0.772213
# Saved figures to: reports/figures/pinn_001/call

# %%
! python scripts/check_price.py --ckpt runs/pinn_001/checkpoint_call.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
#
# ==== PRICE CHECK ====
# PINN price  : 10.423621
# BS price    : 10.450584
# Abs error   : 0.026962
# ...

# %%
# put option
! python -m src.training.train
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ep     1/5000 | loss=1.034e+05 (pde=4.11e-03, term=1.12e+03, bc=4.76e+03) | 0.7s
# ep   100/5000 | loss=7.529e+04 (pde=7.32e-01, term=8.29e+02, bc=3.38e+03) | 54.2s
# ep   200/5000 | loss=7.376e+04 (pde=1.15e+00, term=8.50e+02, bc=3.12e+03) | 109.3s
# ep   300/5000 | loss=7.372e+04 (pde=1.23e+00, term=8.57e+02, bc=3.09e+03) | 166.4s
# ep   400/5000 | loss=5.446e+04 (pde=1.32e+00, term=5.32e+02, bc=2.79e+03) | 223.6s
# ep   500/5000 | loss=2.239e+04 (pde=6.46e+00, term=1.77e+02, bc=1.36e+03) | 281.5s
# ...

# %%
! python -m src.evaluation.greek --ckpt runs/pinn_001/checkpoint_put.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [t=0.000] price RMSE=0.036246, max_abs_err=0.168156 | delta RMSE=0.045101 | gamma RMSE=0.004959 | theta RMSE=0.314278
# [t=0.000] worst at S=3.007519: PINN=92.283580, BS=92.115424, err=0.168156
# [t=0.500] price RMSE=0.052223, max_abs_err=0.307126 | delta RMSE=0.044444 | gamma RMSE=0.005243 | theta RMSE=0.265173
# [t=0.500] worst at S=4.511278: PINN=93.326839, BS=93.019713, err=0.307126
# Saved figures to: reports/figures/pinn_001/put

# %%
! python scripts/check_price.py --ckpt runs/pinn_001/checkpoint_put.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
#
# ==== PRICE CHECK ====
# PINN price  : 5.607795
# BS price    : 5.573526
# Abs error   : 0.034269
# ...

# %%
! python -m src.training.train
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ep     1/5000 | loss=6.376e+05 (pde=7.98e-02, term=8.74e+03, bc=2.01e+04) | 1.2s
# ep   100/5000 | loss=5.008e+05 (pde=1.28e-01, term=6.67e+03, bc=1.67e+04) | 57.3s
# ep   200/5000 | loss=4.351e+05 (pde=3.51e-01, term=5.71e+03, bc=1.50e+04) | 114.0s
# ep   300/5000 | loss=3.919e+05 (pde=6.26e-01, term=5.11e+03, bc=1.37e+04) | 171.0s
# ep   400/5000 | loss=3.648e+05 (pde=9.14e-01, term=4.75e+03, bc=1.27e+04) | 227.8s
# ep   500/5000 | loss=3.487e+05 (pde=1.19e+00, term=4.56e+03, bc=1.21e+04) | 284.7s
# ...

# %%
! python -m src.evaluation.greek --ckpt runs/pinn_002/checkpoint_call.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [t=0.000] price RMSE=0.238971, max_abs_err=1.797093 | delta RMSE=0.034510 | gamma RMSE=0.004554 | theta RMSE=1.312768
# [t=0.000] worst at S=300.000000: PINN=198.701659, BS=200.498752, err=-1.797093
# [t=0.125] price RMSE=0.202356, max_abs_err=1.230010 | delta RMSE=0.034735 | gamma RMSE=0.007401 | theta RMSE=0.826668
# [t=0.125] worst at S=300.000000: PINN=199.019677, BS=200.249688, err=-1.230010
# Saved figures to: reports/figures/pinn_002/call

# %%
! python scripts/check_price.py --ckpt runs/pinn_002/checkpoint_call.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
#
# ==== PRICE CHECK ====
# PINN price  : 2.315240
# BS price    : 2.248843
# Abs error   : 0.066397
# ...

# %%
# second contract put option
! python -m src.training.train
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ep     1/5000 | loss=1.056e+05 (pde=3.18e-04, term=1.12e+03, bc=4.97e+03) | 0.8s
# ep   100/5000 | loss=7.713e+04 (pde=1.10e-01, term=8.29e+02, bc=3.57e+03) | 56.6s
# ep   200/5000 | loss=7.542e+04 (pde=1.78e-01, term=8.51e+02, bc=3.29e+03) | 113.5s
# ep   300/5000 | loss=7.538e+04 (pde=1.82e-01, term=8.59e+02, bc=3.24e+03) | 170.5s
# ep   400/5000 | loss=3.612e+04 (pde=1.06e+01, term=3.02e+02, bc=2.10e+03) | 227.5s
# ep   500/5000 | loss=1.808e+04 (pde=1.99e+00, term=1.26e+02, bc=1.18e+03) | 284.6s
# ...

# %%
! python -m src.evaluation.greek --ckpt runs/pinn_002/checkpoint_put.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [t=0.000] price RMSE=0.017149, max_abs_err=0.137357 | delta RMSE=0.037327 | gamma RMSE=0.029641 | theta RMSE=0.219142
# [t=0.000] worst at S=0.751880: PINN=98.886725, BS=98.749368, err=0.137357
# [t=0.125] price RMSE=0.021904, max_abs_err=0.206057 | delta RMSE=0.032605 | gamma RMSE=0.032393 | theta RMSE=0.129006
# [t=0.125] worst at S=0.751880: PINN=99.204490, BS=98.998433, err=0.206057
# Saved figures to: reports/figures/pinn_002/put

# %%
! python scripts/check_price.py --ckpt runs/pinn_002/checkpoint_put.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
#
# ==== PRICE CHECK ====
# PINN price  : 1.779436
# BS price    : 1.750091
# Abs error   : 0.029345
# ...
