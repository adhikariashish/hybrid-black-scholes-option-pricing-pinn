# %% [markdown]
# To access files in your Google Drive, you'll need to mount it. This will prompt you to authorize Colab to access your Drive files.

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn')

print(os.getcwd())

# !ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# app	 docs	  notebooks	  reports	  scripts	  tests
# configs  env	  pyproject.toml  run_file.ipynb  src
# data	 LICENSE  README.md	  runs		  test_run.ipynb

# %%
! python -m src.training.train
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ep     1/5000 | loss=6.414e+05 (pde=1.54e-03, term=8.73e+03, bc=2.05e+04) | 1.3s
# ep   100/5000 | loss=5.029e+05 (pde=8.65e-01, term=6.64e+03, bc=1.71e+04) | 57.6s
# ep   200/5000 | loss=4.374e+05 (pde=2.28e+00, term=5.69e+03, bc=1.53e+04) | 115.0s
# ep   300/5000 | loss=3.944e+05 (pde=4.01e+00, term=5.09e+03, bc=1.40e+04) | 172.5s
# ep   400/5000 | loss=3.673e+05 (pde=5.82e+00, term=4.74e+03, bc=1.30e+04) | 230.0s
# ep   500/5000 | loss=3.514e+05 (pde=7.54e+00, term=4.55e+03, bc=1.24e+04) | 287.3s
# ...

# %%
! python -m src.evaluation.greek --ckpt runs/pinn_v3/checkpoint.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [t=0.000] price RMSE=0.605609, max_abs_err=2.973294
# [t=0.500] price RMSE=0.175937, max_abs_err=0.745612
# Saved figures to: reports/figures/pinn_v3

# %%
! python scripts/check_price.py --ckpt runs/pinn_v3/checkpoint.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
#
# ==== PRICE CHECK ====
# PINN price  : 10.406507
# BS price    : 10.450584
# Abs error   : 0.044077
# ...

# %%
! python -m src.training.train
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ep     1/5000 | loss=6.422e+05 (pde=7.94e-04, term=8.74e+03, bc=2.05e+04) | 1.2s
# ep   100/5000 | loss=5.048e+05 (pde=8.35e-01, term=6.67e+03, bc=1.71e+04) | 56.9s
# ep   200/5000 | loss=4.389e+05 (pde=2.23e+00, term=5.71e+03, bc=1.53e+04) | 115.1s
# ep   300/5000 | loss=3.954e+05 (pde=3.95e+00, term=5.10e+03, bc=1.40e+04) | 173.1s
# ep   400/5000 | loss=3.681e+05 (pde=5.76e+00, term=4.75e+03, bc=1.31e+04) | 231.0s
# ep   500/5000 | loss=3.519e+05 (pde=7.47e+00, term=4.56e+03, bc=1.24e+04) | 289.0s
# ...

# %%
! python -m src.evaluation.greek --ckpt runs/pinn_v4/checkpoint.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:841: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at /pytorch/aten/src/ATen/cuda/CublasHandlePool.cpp:270.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [t=0.000] price RMSE=0.549123, max_abs_err=2.727471
# [t=0.500] price RMSE=0.162764, max_abs_err=0.651641
# Saved figures to: reports/figures/pinn_v4

# %%
! python scripts/check_price.py --ckpt runs/pinn_v4/checkpoint.pt
# Out:
# /content/drive/Othercomputers/Razer/hybrid-black-scholes-option-pricing-pinn
#
# ==== PRICE CHECK ====
# PINN price  : 10.378909
# BS price    : 10.450584
# Abs error   : 0.071675
# ...
